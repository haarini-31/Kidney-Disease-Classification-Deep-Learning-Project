# %%
#config box
d={"key":"val","key1":"val1"}

# %%
d['key']
# Out:
# 'val'

# %%
from box import ConfigBox

# %%
d2=ConfigBox({"key":"val","key1":"val1"})

# %%
d2.key1
# Out:
# 'val1'

# %%
type(d2)
# Out:
# box.config_box.ConfigBox

# %%
type(d)
# Out:
# dict

# %%
#ensure annotations
def get_prodict(x:int,y:int)->int:
    return x*y

# %%
get_prodict(2,3)
# Out:
# 6

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_prodict(x:int,y:int)->int:
    return x*y

# %%
get_prodict(2,3)
# Out:
# 6

# %%
import gdown

# %%
url="https://drive.google.com/file/d/1Rorx3PS4q5k5NSoy56xrmo-HTcC0RqTQ/view?usp=drive_link"

# %%
file_id=url.split("/")[-2]
file_id
# Out:
# '1Rorx3PS4q5k5NSoy56xrmo-HTcC0RqTQ'

# %%
prefix="https://drive.google.com/uc?export=download&id="
gdown.download(prefix+file_id,"kindey dataset.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1Rorx3PS4q5k5NSoy56xrmo-HTcC0RqTQ
# From (redirected): https://drive.google.com/uc?export=download&id=1Rorx3PS4q5k5NSoy56xrmo-HTcC0RqTQ&confirm=t&uuid=82bdc941-fa5e-49c1-aceb-f5e765a3877e
# To: c:\Users\haari\OneDrive\Desktop\aiml 2026\Kidney-Disease-Classification-Deep-Learning-Project\research\research\templates\kindey dataset.zip
# 100%|██████████| 1.63G/1.63G [00:58<00:00, 27.7MB/s]
# 'kindey dataset.zip'
